# %%
import indicator

# %%
dir(indicator)
# Out:
# ['LinearRegression',
#  'Momentum',
#  'MovingLow',
#  'Sma',
#  'Vwap',
#  'ZScore',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  'deque',
#  'mean',
#  'numpy',
#  'polyfit',
#  'polyval',
#  'rsquared',
#  'sharpeRatio',
#  'sqrt',
#  'stats',
#  'stddev']

# %%
import numpy as np

# %%
arr = np.random.random(100)

# %%
arr
# Out:
# array([ 0.84167844,  0.63136532,  0.37331218,  0.60382245,  0.60923408,
#         0.93223926,  0.68619104,  0.4457421 ,  0.22723882,  0.11701741,
#         0.1636032 ,  0.98387522,  0.4116318 ,  0.38269857,  0.95915109,
#         0.14518972,  0.1119041 ,  0.58238222,  0.33942868,  0.93287726,
#         0.48192486,  0.21042538,  0.05564494,  0.53408501,  0.04941986,
#         0.08280666,  0.335867  ,  0.07176387,  0.7442724 ,  0.55420703,
#         0.02696518,  0.13935055,  0.50913163,  0.28170093,  0.99021681,
#         0.77126307,  0.09459771,  0.17445566,  0.6818669 ,  0.453172  ,
#         0.04825765,  0.28504084,  0.37021378,  0.60706002,  0.14292017,
#         0.15806694,  0.18834218,  0.69177355,  0.78939315,  0.32374381,
#         0.65128382,  0.24406551,  0.98257407,  0.89248597,  0.27058178,
#         0.34682937,  0.35704393,  0.5264796 ,  0.90383039,  0.66420824,
#         0.62494653,  0.31462326,  0.06491838,  0.57931692,  0.93304836,
# ...

# %%
mean(arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7706df46829f> in <module>()
# ----> 1 mean(arr)
#
# NameError: name 'mean' is not defined

# %%
indicator.mean(arr)
# Out:
# 0.46639782728832008

# %%
indicator.stddev(arr)
# Out:
# 0.28845301657018241

# %%
import pandas as pd

# %%
import pandas.io.data as web
# Out:
# /Users/adantra/anaconda/envs/default/lib/python2.7/site-packages/pandas/io/data.py:35: FutureWarning:
# The pandas.io.data module is moved to a separate package (pandas-datareader) and will be removed from pandas in a future version.
# After installing the pandas-datareader package (https://github.com/pydata/pandas-datareader), you can change the import ``from pandas.io import data, wb`` to ``from pandas_datareader import data, wb``.
#   FutureWarning)

# %%
import datetime

# %%
start = datetime.datetime(2014,1,1)

# %%
end = datetime.datetime(2015,1,1)

# %%
aapl = web.DataReader("aapl",'yahoo',start,end)

# %%
aapl.head()
# Out:
#                   Open        High         Low      Close     Volume  \
# Date
# 2014-01-02  555.680008  557.029999  552.020004  75.682745   58671200
# 2014-01-03  552.860023  553.699989  540.429993  74.020309   98116900
# 2014-01-06  537.450005  546.800018  533.599983  74.423944  103152700
# 2014-01-07  544.320015  545.959999  537.919975  73.891693   79302300
# 2014-01-08  538.809982  545.559990  538.689980  74.359639   64632400
#
#             Adj Close
# Date
# 2014-01-02  75.682745
# 2014-01-03  74.020309
# 2014-01-06  74.423944
# 2014-01-07  73.891693
# 2014-01-08  74.359639

# %%
aapl['Open'] = aapl['Open']*aaplaapl['Adj Close']

# %%
import pandasImpl

# %%
dir(pandasImpl)
# Out:
# ['ACCDIST',
#  'ADX',
#  'ATR',
#  'BBANDS',
#  'CCI',
#  'COPP',
#  'Categorical',
#  'CategoricalIndex',
#  'Chaikin',
#  'DONCH',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'EMA',
#  'EOM',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'FORCE',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'KELCH',
#  'KST',
#  'MA',
#  'MACD',
#  'MFI',
#  'MOM',
#  'MassI',
#  'MultiIndex',
#  'NaT',
#  'OBV',
#  'PPSR',
#  'Panel',
#  'Panel4D',
#  'Period',
#  'PeriodIndex',
#  'ROC',
#  'RSI',
#  'RangeIndex',
#  'STDDEV',
#  'STO',
#  'STOK',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseList',
#  'SparsePanel',
#  'SparseSeries',
#  'SparseTimeSeries',
#  'TRIX',
#  'TSI',
#  'Term',
#  'TimeGrouper',
#  'TimeSeries',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'ULTOSC',
#  'Vortex',
#  'WidePanel',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  'acos',
# ...

# %%
aapl=pandasImpl.CCI(aapl,40)
# Out:
# pandasImpl.py:299: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=40,center=False).mean()
#   CCI = Series((PP - rolling_mean(PP, n)) / rolling_std(PP, n), name = 'CCI_' + str(n))
# pandasImpl.py:299: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=40,center=False).std()
#   CCI = Series((PP - rolling_mean(PP, n)) / rolling_std(PP, n), name = 'CCI_' + str(n))

# %%
aapl=aapl.dropna()

# %%
aapl = pandasImpl.MACD(aapl,20,40)

# %%
aapl.head()
# Out:
#                   Open        High         Low      Close    Volume  \
# Date
# 2014-03-10  528.360023  533.330017  528.339996  73.078655  44646000
# 2014-03-11  535.450012  538.740021  532.589973  73.790281  69806100
# 2014-03-12  534.510017  537.349976  532.000000  73.861858  49831600
# 2014-03-13  537.440018  539.659988  529.159988  73.041495  64435700
# 2014-03-14  528.789993  530.890015  523.000008  72.221125  59299800
#
#             Adj Close    CCI_20  MACD_20_40  MACDsign_20_40  MACDdiff_20_40
# Date
# 2014-03-10  73.078655 -0.102480    0.003972       -0.032698        0.036670
# 2014-03-11  73.790281  0.510093    0.045011       -0.014747        0.059757
# 2014-03-12  73.861858  0.375327    0.083087        0.007173        0.075913
# 2014-03-13  73.041495  0.303762    0.080495        0.023216        0.057279
# 2014-03-14  72.221125 -0.668804    0.042827        0.027427        0.015399

# %%
# %matplotlib inline

# %%
numpy_aapl = aapl.as_matrix()

# %%
numpy_aapl
# Out:
# array([[  5.28360023e+02,   5.33330017e+02,   5.28339996e+02, ...,
#          -3.26980401e-02,   3.66703179e-02,              nan],
#        [  5.35450012e+02,   5.38740021e+02,   5.32589973e+02, ...,
#          -1.47469813e-02,   5.97574837e-02,              nan],
#        [  5.34510017e+02,   5.37349976e+02,   5.32000000e+02, ...,
#           7.17348677e-03,   7.59134106e-02,              nan],
#        ...,
#        [  1.13790001e+02,   1.14769997e+02,   1.13699997e+02, ...,
#           1.46532639e+00,  -2.44902168e-01,   4.31066017e-01],
#        [  1.13639999e+02,   1.13919998e+02,   1.12110001e+02, ...,
#           1.40537686e+00,  -2.39798110e-01,  -2.71665893e-03],
#        [  1.12820000e+02,   1.13129997e+02,   1.10209999e+02, ...,
#           1.32744879e+00,  -3.11712302e-01,  -5.40472523e-01]])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(aapl.index,aapl.CCI_40,aapl.index,aapl.CCI_20)

# %%
plt.plot(aapl.index,aapl.MACDdiff_20_40)

# %%
pcln.tail()
# Out:
#                    Open         High          Low        Close  Volume  \
# Date
# 2014-12-24  1148.000000  1152.400024  1143.040039  1149.780029  166500
# 2014-12-26  1152.430054  1160.439941  1150.109985  1156.219971  280600
# 2014-12-29  1154.640015  1169.609985  1150.560059  1160.040039  472600
# 2014-12-30  1155.489990  1161.119995  1144.060059  1148.650024  357800
# 2014-12-31  1150.930054  1154.000000  1140.209961  1140.209961  482500
#
#               Adj Close    CCI_40  MACD_20_40  MACDsign_20_40  MACDdiff_20_40  \
# Date
# 2014-12-24  1149.780029  0.343030   -7.335437       -9.033282        1.697846
# 2014-12-26  1156.219971  0.552248   -5.516658       -8.329958        2.813299
# 2014-12-29  1160.040039  0.671201   -3.748268       -7.413620        3.665352
# 2014-12-30  1148.650024  0.458855   -2.738081       -6.478512        3.740431
# 2014-12-31  1140.209961  0.329337   -2.248070       -5.632424        3.384354
#
#               CCI_20
# Date
# 2014-12-24  0.779488
# ...

# %%
aapl['diff_1'] = -aapl['Adj Close'].diff(-10)

# %%
goog = web.DataReader("googl",'yahoo',start,end)

# %%
goog = pandasImpl.BBANDS(goog,20)

# %%
goog=goog.dropna()

# %%
goog.head()
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2014-01-30  1144.999987  1152.490048  1127.250054  1135.389977  10172600
# 2014-01-31  1171.350076  1186.540071  1151.129959  1180.969963  11121400
# 2014-02-03  1179.200006  1181.720066  1132.010060  1133.430025   9129000
# 2014-02-04  1137.990036  1154.999987  1137.010060  1138.160032   5618100
# 2014-02-05  1143.380026  1150.769968  1128.020035  1143.200031   4784200
#
#              Adj Close  BollingerB_20  Bollinger%b_20
# Date
# 2014-01-30  568.263252       0.070341        0.515606
# 2014-01-31  591.076057       0.076862        0.996750
# 2014-02-03  567.282295       0.072045        0.432620
# 2014-02-04  569.649666       0.069742        0.476845
# 2014-02-05  572.172188       0.069766        0.537487

# %%
goog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 233 entries, 2014-01-30 to 2014-12-31
# Data columns (total 8 columns):
# Open              233 non-null float64
# High              233 non-null float64
# Low               233 non-null float64
# Close             233 non-null float64
# Volume            233 non-null int64
# Adj Close         233 non-null float64
# BollingerB_20     233 non-null float64
# Bollinger%b_20    233 non-null float64
# dtypes: float64(7), int64(1)
# memory usage: 16.4 KB

# %%
goog.describe()
# Out:
#               Open         High          Low        Close           Volume  \
# count   233.000000   233.000000   233.000000   233.000000       233.000000
# mean    680.751850   685.417641   674.114511   679.707214   2507778.111588
# std     245.446287   246.619244   243.259036   244.574450   1510126.659364
# min     499.859985   509.070007   497.190002   498.160004    737700.000000
# 25%     547.000000   551.190002   543.799988   545.890015   1517300.000000
# 50%     574.570007   579.719971   569.159973   573.599976   2004300.000000
# 75%     596.890015   598.450012   592.169983   595.440002   3160600.000000
# max    1226.800064  1228.880013  1218.600020  1220.169982  11121400.000000
#
#         Adj Close  BollingerB_20  Bollinger%b_20
# count  233.000000     233.000000      233.000000
# mean   568.164366       0.170930        0.463951
# std     26.102872       0.323505        0.329017
# min    498.160004       0.028561       -0.527804
# ...

# %%
pd.__version__
# Out:
# u'0.17.0'

# %%
sp500options = Options('spy', 'yahoo')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-b9e7c2d766c2> in <module>()
# ----> 1 sp500options = Options('spy', 'yahoo')
#
# NameError: name 'Options' is not defined

# %%
import pandas as pd

# %%
import pandas.io.data as web
# Out:
# /Users/adantra/anaconda/envs/default/lib/python2.7/site-packages/pandas/io/data.py:35: FutureWarning:
# The pandas.io.data module is moved to a separate package (pandas-datareader) and will be removed from pandas in a future version.
# After installing the pandas-datareader package (https://github.com/pydata/pandas-datareader), you can change the import ``from pandas.io import data, wb`` to ``from pandas_datareader import data, wb``.
#   FutureWarning)

# %%
from pandas_datareader import data, wb

# %%
from pandas.io.data import Options

# %%
goog = Options('googl', 'yahoo')

# %%
data = goog.get_all_data()

# %%
data.tail()
# Out:
#                                               Last    Bid    Ask  Chg  PctChg  \
# Strike Expiry     Type Symbol
# 1160.0 2020-01-17 put  GOOGL170120P01160000    0.0  425.5  430.5  0.0   0.00%
# 1180.0 2019-01-18 call GOOGL180119C01180000    9.8    9.4   11.0  0.0   0.00%
#                   put  GOOGL180119P01180000  428.0  419.1  424.0  0.0   0.00%
#        2020-01-17 call GOOGL170120C01180000    1.0    0.6    1.4  0.1  11.11%
#                   put  GOOGL170120P01180000    0.0  445.5  450.5  0.0   0.00%
#
#                                              Vol  Open_Int      IV   Root  \
# Strike Expiry     Type Symbol
# 1160.0 2020-01-17 put  GOOGL170120P01160000    0         0  53.32%  GOOGL
# 1180.0 2019-01-18 call GOOGL180119C01180000   14      1229  22.61%  GOOGL
#                   put  GOOGL180119P01180000   48        69  28.22%  GOOGL
#        2020-01-17 call GOOGL170120C01180000   10       805  22.97%  GOOGL
# ...

# %%
data.loc[(400, slice(None), 'put'),:].iloc[0:5, 0:5]
# Out:
#                                              Last   Bid    Ask  Chg  PctChg
# Strike Expiry     Type Symbol
# 400.0  2016-09-16 put  GOOGL160916P00400000   0.3  0.00   0.95  0.0   0.00%
#        2019-01-18 put  GOOGL180119P00400000   8.3  7.00  10.00  1.6  23.88%
#        2020-01-17 put  GOOGL170120P00400000   1.7  1.15   1.50  0.0   0.00%

# %%
expiry = datetime.date(2016, 1, 1)

# %%
import datetime

# %%
data = goog.get_call_data(expiry=expiry)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-01f90b6ca566> in <module>()
# ----> 1 data = goog.get_call_data(expiry=expiry)
#
# NameError: name 'expiry' is not defined

# %%
data
# Out:
#                                              Last    Bid    Ask   Chg  \
# Strike Expiry     Type Symbol
# 65.0   2008-04-16 call AAPL160408C00065000  46.90  45.95  46.30  0.00
# 75.0   2008-04-16 call AAPL160408C00075000  31.80  31.65  31.90  0.00
# 80.0   2008-04-16 call AAPL160408C00080000  26.76  26.65  26.90  0.00
# 85.0   2008-04-16 call AAPL160408C00085000   0.00  16.20  16.45  0.00
# 86.5   2008-04-16 call AAPL160408C00086500   0.00  14.75  14.95  0.00
# 87.0   2008-04-16 call AAPL160408C00087000   0.00  14.25  14.45  0.00
# 87.5   2008-04-16 call AAPL160408C00087500   0.00  13.75  14.00  0.00
# 88.5   2008-04-16 call AAPL160408C00088500  13.80  18.20  18.40  0.00
# 89.0   2008-04-16 call AAPL160408C00089000  20.00  20.85  21.10  0.00
# 90.0   2008-04-16 call AAPL160408C00090000  18.81  19.85  20.15  0.00
# 91.0   2008-04-16 call AAPL160408C00091000   0.00  10.40  10.65  0.00
# 91.5   2008-04-16 call AAPL160408C00091500   0.00   9.95  10.15  0.00
# ...

# %%
data = aapl.get_all_data()

# %%
data.iloc[0:5, 0:5]
# Out:
#                                             Last   Bid    Ask  Chg PctChg
# Strike Expiry     Type Symbol
# 10.0   2017-06-16 call AAPL160617C00010000   0.0  91.0  91.45  0.0  0.00%
#                   put  AAPL160617P00010000   0.0   0.0   0.03  0.0  0.00%
# 12.5   2017-06-16 put  AAPL160617P00012500   0.0   0.0   0.03  0.0  0.00%
# 15.0   2017-06-16 call AAPL160617C00015000   0.0  86.0  86.45  0.0  0.00%
#                   put  AAPL160617P00015000   0.0   0.0   0.03  0.0  0.00%

# %% [markdown]
# ## data.loc[(115, slice(None), 'put'),:].iloc[0:5, 0:5]

# %%
data.loc[(datetime(2016,4,16), slice(None), 'put'),:].iloc[0:5, 0:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-068daadd010a> in <module>()
# ----> 1 data.loc[(datetime(2016,4,16), slice(None), 'put'),:].iloc[0:5, 0:5]
#
# TypeError: 'module' object is not callable

# %%
symbol = 'AAPL160416C00105000'

# %%
data[symbol]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-03f52c7192ce> in <module>()
# ----> 1 data[symbol]
#
# /Users/adantra/anaconda/envs/default/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /Users/adantra/anaconda/envs/default/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# /Users/adantra/anaconda/envs/default/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...

# %%
datetime.date.today()
# Out:
# datetime.date(2016, 4, 6)

# %%
goog.puts
# Out:
#                                               Last    Bid     Ask   Chg  \
# Strike Expiry     Type Symbol
# 560.0  2008-04-16 put  GOOGL160408P00560000   0.05   0.00    0.25  0.00
# 570.0  2008-04-16 put  GOOGL160408P00570000   0.45   0.00    0.30  0.00
# 580.0  2008-04-16 put  GOOGL160408P00580000   0.00   0.00    0.55  0.00
# 590.0  2008-04-16 put  GOOGL160408P00590000   0.00   0.00    0.50  0.00
# 600.0  2008-04-16 put  GOOGL160408P00600000   0.05   0.00    0.25 -0.30
# 610.0  2008-04-16 put  GOOGL160408P00610000   0.15   0.00    0.30 -0.27
# 620.0  2008-04-16 put  GOOGL160408P00620000   0.47   0.00    0.25  0.00
# 630.0  2008-04-16 put  GOOGL160408P00630000   0.10   0.00    0.30 -0.13
# 640.0  2008-04-16 put  GOOGL160408P00640000   0.00   1.05    1.70  0.00
# 650.0  2008-04-16 put  GOOGL160408P00650000   0.23   0.00    0.25  0.00
# 660.0  2008-04-16 put  GOOGL160408P00660000   0.09   0.00    0.25  0.00
# 670.0  2008-04-16 put  GOOGL160408P00670000   0.26   0.00    0.25  0.00
# ...

# %%
import numpy as np

# %%
r=np.array([[np.cos(-az),-np.sin(-az),0],[np.sin(-az),np.cos(-az),0],[0,0,1]])

# %%
az=135.0/180.0*np.pi
print az
# Out:
# 2.35619449019

# %% [raw]
# az=135/180*np.pi
# print az

# %%
p1=3233

# %%
s1 = np.array([[4766,0,0],[0,4766,0],[0,0,5463]])

# %%
se1 = s1-p1

# %%
left= np.dot(r,s1)

# %%
s_rot = np.dot(left,r)

# %%
print s_rot
print s1
# Out:
# [[ -7.29828005e-13  -4.76600000e+03   0.00000000e+00]
#  [  4.76600000e+03  -8.75374665e-13   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   5.46300000e+03]]
# [[4766    0    0]
#  [   0 4766    0]
#  [   0    0 5463]]

# %%
n = np.array([0.87,0.26,0.42])

# %%
traction = np.dot(s_rot,n)

# %%
traction
# Out:
# array([-1239.16,  4146.42,  2294.46])

# %%
shear = traction - np.dot(traction,n)*n

# %%
shear
# Out:
# array([-2077.555684,  3895.864968,  1889.717256])

# %%
mod_t=np.dot(traction,traction)

# %%
mod_s = np.dot(shear,shear)

# %%
mod_t=np.sqrt(mod_t)

# %%
mod_s=np.sqrt(mod_s)

# %%
print mod_t,mod_s
# Out:
# 4898.25101578 4802.606873

# %%
def rotate(s):
    r=np.array([[np.cos(-az),-np.sin(-az),0],[np.sin(-az),np.cos(-az),0],[0,0,1]])
    left= np.dot(r,s1)
    s_rot = np.dot(left,r)
    return s_rot

# %%
mp1=np.array([[p1,0,0],[0,p1,0],[0,0,p1]])

# %%
ss_r1 = rotate(s1)

# %%
ss1 = ss_r1 - mp1
print ss1
print ss_r1
# Out:
# [[-3233. -4766.     0.]
#  [ 4766. -3233.     0.]
#  [    0.     0.  2230.]]
# [[ -7.29828005e-13  -4.76600000e+03   0.00000000e+00]
#  [  4.76600000e+03  -8.75374665e-13   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   5.46300000e+03]]

# %%
def traction(s,n):
    t = np.dot(s,n)
    mod_t = np.sqrt(np.dot(t,t))
    shear = t-np.dot(t,n)*n
    mod_s = np.sqrt(np.dot(shear,shear))
    return mod_t,mod_s

# %%
n
# Out:
# array([ 0.87,  0.26,  0.42])

# %%
mod_t,mod_s = traction(ss1_r1,n)
print mod_t, mod_s
# Out:
# 4728.2207107 3755.44751716

# %%
ss_r1
# Out:
# array([[ -7.29828005e-13,  -4.76600000e+03,   0.00000000e+00],
#        [  4.76600000e+03,  -8.75374665e-13,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   5.46300000e+03]])

# %%
ss1
# Out:
# array([[ 1533, -3233, -3233],
#        [-3233,  1533, -3233],
#        [-3233, -3233,  2230]])

# %%
ss1
# Out:
# array([[-3233., -4766.,     0.],
#        [ 4766., -3233.,     0.],
#        [    0.,     0.,  2230.]])

# %%
import numpy as np
def compute(st,press,n,az):
    az=az/180.0*np.pi
    # rotate back (-az) to align with x-y axys
    #r=np.array([[np.cos(-az),np.sin(-az),0],[-np.sin(-az),np.cos(-az),0],[0,0,1]])
    axis = [0,0,1]
    theta = -az
    r = rotation_matrix(axis, theta)
    print r
    p = np.array([[press,0,0],[0,press,0],[0,0,press]])
    st_rot = np.dot(r.transpose(),np.dot(st,r)) 
    print 50*'#'
    print np.trace(st)
    print np.trace(st_rot)
    print 50*'#'
    #print st_rot
    #print st
    # compute effective stress 
    se_rot =st_rot-p
    #compute traction using total stress
    t = np.dot(st_rot,n)
    
    tp = t-press
    #print tp
    mod_tp = np.sqrt(np.dot(t,t))-press
    mod_t = np.sqrt(np.dot(t,t))
    #mod_t = np.sqrt(np.dot(tp,tp))
    #computed from traction, no pore pressure
    shear = t-np.dot(t,n)*n
    #shear = 
    #print t
    #print shear
    #print np.dot(t,n)*n
    #print shear
    #print t
    #print mod_t**2
    #print 1.0/9*(st_rot[0,0]+st_rot[1,1]+st_rot[2,2])**2
    #mod_s = np.sqrt(mod_t**2- 1.0/9*(st_rot[0,0]+st_rot[1,1]+st_rot[2,2])**2  )
    #print 1.0/9*(st_rot[0,0]+st_rot[1,1]+st_rot[2,2])**2
    #print np.dot(t,t)
    #print st_rot[2,2]
    mod_s = np.sqrt(np.dot(shear,shear))
    return mod_tp, mod_s

# %%
n1=n
n
n1
nn = np.array([1,0,0])

# %%
tr1,sh1 = compute(s1,p1,n1,105)
print tr1,sh1
# Out:
# [[-0.25881905  0.96592583  0.        ]
#  [-0.96592583 -0.25881905  0.        ]
#  [ 0.          0.          1.        ]]
# ##################################################
# 14995
# 14995.0
# ##################################################
# 1665.25101578 265.730650083

# %%
p1
# Out:
# 3233

# %%
s2 =np.array([[3541,0,0],[0,3541,0],[0,0,5563]])

# %%
n2=n1

# %%
tr2,sh2 = compute(s2,p2,n2,105)
print tr2,sh2
# Out:
# [[-0.25881905  0.96592583  0.        ]
#  [-0.96592583 -0.25881905  0.        ]
#  [ 0.          0.          1.        ]]
# ##################################################
# 12645
# 12645.0
# ##################################################
# 3394.56762631 770.78797028

# %%
n3 = np.array([0.72,0.5,0.48])
s3=s1
p3=p1

# %%
tr3,sh3 = compute(s1,p1,n3,105)
print tr3,sh3
# Out:
# [[-0.25881905  0.96592583  0.        ]
#  [-0.96592583 -0.25881905  0.        ]
#  [ 0.          0.          1.        ]]
# ##################################################
# 14995
# 14995.0
# ##################################################
# 1699.56131518 293.50563649

# %%
n4=n3;p4=580;s4=s2

# %%
tr4,sh4 = compute(s2,p2,n3,105)
print tr4,sh4
# Out:
# [[-0.25881905  0.96592583  0.        ]
#  [-0.96592583 -0.25881905  0.        ]
#  [ 0.          0.          1.        ]]
# ##################################################
# 12645
# 12645.0
# ##################################################
# 3514.49681133 851.30213162

# %%
n5=np.array([0.74,0.41,0.53])

# %%
s3 = np.array([[5183,0,0],[0,5183,0],[0,0,5959]])
s5=np.array([[5183,0,0],[0,5183,0],[0,0,5959]])
p5=3508.26

# %%
tr5,sh5 = compute(s5,p5,n5,105)
print tr5,sh5
# Out:
# [[-0.25881905  0.96592583  0.        ]
#  [-0.96592583 -0.25881905  0.        ]
#  [ 0.          0.          1.        ]]
# ##################################################
# 16325
# 16325.0
# ##################################################
# 1895.52279266 349.013914626

# %%
s6=np.array([[3832.5,0,0],[0,3832.5,0],[0,0,5959]])

# %%
n6=n5

# %%
p6 = 580

# %%
tr6,sh6 = compute(s6,p6,n6,105)
print tr6,sh6
# Out:
# [[-0.25881905  0.96592583  0.        ]
#  [-0.96592583 -0.25881905  0.        ]
#  [ 0.          0.          1.        ]]
# ##################################################
# 13624.0
# 13624.0
# ##################################################
# 3946.24692776 955.212909368

# %%
n7=np.array([0.87,0.26,0.42])

# %%
s7=np.array([[2635,0,0],[0,203,0],[0,0,2066]])

# %%
n7=np.array([0.87,0.26,0.42])

# %%
p7=0

# %%
tr7,sh7 = compute(s7,p7,n7,135)
print tr7,sh7
# Out:
# [[-0.25881905  0.96592583  0.        ]
#  [-0.96592583 -0.25881905  0.        ]
#  [ 0.          0.          1.        ]]
# ##################################################
# 4904
# 4904.0
# ##################################################
# 889.701723062 712.214904381

# %%
s8 = np.array([[2455,0,0],[0,382.9,0],[0,0,2066]])

# %%
n8=n7

# %%
p8=p7

# %%
tr8,sh8 = compute(s8,p8,n8,135)
print tr8,sh8
# Out:
# [[-0.25881905  0.96592583  0.        ]
#  [-0.96592583 -0.25881905  0.        ]
#  [ 0.          0.          1.        ]]
# ##################################################
# 4903.9
# 4903.9
# ##################################################
# 936.901998523 643.199499469

# %%
n9=np.array([0.72,0.5,0.48])

# %%
s9 =s7

# %%
p9=p7

# %%
tr9,sh9 = compute(s9,p9,n9,135)
print tr9,sh9
# Out:
# [[-0.25881905  0.96592583  0.        ]
#  [-0.96592583 -0.25881905  0.        ]
#  [ 0.          0.          1.        ]]
# ##################################################
# 4904
# 4904.0
# ##################################################
# 1273.70694473 951.7492069

# %%
import numpy as np

# %%
n10=n9

# %%
s10 = s8

# %%
tr10,sh10 = compute(s10,p9,n10,135)
print tr10,sh10
# Out:
# [[-0.25881905  0.96592583  0.        ]
#  [-0.96592583 -0.25881905  0.        ]
#  [ 0.          0.          1.        ]]
# ##################################################
# 4903.9
# 4903.9
# ##################################################
# 1270.21309851 839.667387259

# %%
import numpy as np
import math

def rotation_matrix(axis, theta):
    """
    Return the rotation matrix associated with counterclockwise rotation about
    the given axis by theta radians.
    """
    axis = np.asarray(axis)
    theta = np.asarray(theta)
    axis = axis/math.sqrt(np.dot(axis, axis))
    a = math.cos(theta/2.0)
    b, c, d = -axis*math.sin(theta/2.0)
    aa, bb, cc, dd = a*a, b*b, c*c, d*d
    bc, ad, ac, ab, bd, cd = b*c, a*d, a*c, a*b, b*d, c*d
    return np.array([[aa+bb-cc-dd, 2*(bc+ad), 2*(bd-ac)],
                     [2*(bc-ad), aa+cc-bb-dd, 2*(cd+ab)],
                     [2*(bd+ac), 2*(cd-ab), aa+dd-bb-cc]])

# %%
axis=[0,0,1]

# %%
theta = 105.*np.pi/180

# %%
rot = rotation_matrix(axis,theta)

# %%
rot
# Out:
# array([[-0.25881905, -0.96592583,  0.        ],
#        [ 0.96592583, -0.25881905,  0.        ],
#        [ 0.        ,  0.        ,  1.        ]])

# %%
r=np.array([[np.cos(theta),np.sin(theta),0],[-np.sin(theta),np.cos(theta),0],[0,0,1]])

# %%
r
# Out:
# array([[-0.25881905,  0.96592583,  0.        ],
#        [-0.96592583, -0.25881905,  0.        ],
#        [ 0.        ,  0.        ,  1.        ]])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %%
# %matplotlib inline

# %%
quiver(0, 0, 0, n1[0], n1[1], n1[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-401-67dc894e98dc> in <module>()
# ----> 1 quiver(0, 0, 0, n1[0], n1[1], n1[2])
#
# NameError: name 'quiver' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-404-7bb37bbfa5ea> in <module>()
# ----> 1 Axes3D.quiver(0, 0, 0, n1[0], n1[1], n1[2])
#
# TypeError: unbound method quiver() must be called with Axes3D instance as first argument (got int instance instead)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#Q=ax.quiver(0,0,0, n1[0], n1[1], n1[2])
#Q=ax.plot([1,1,1], [0,1,0])
x=np.array([0,n10[0]])
y=np.array([0,n10[1]])
z=np.array([0,n10[2]])
Q=ax.plot(x,y,z)
n10
# Out:
# array([ 0.72,  0.5 ,  0.48])

# %%
ax = fig.add_subplot(111, projection='3d')
Q=ax.plot([0,0,0], [0,1,1])

# %%
x = 0.1*np.arange(10)

# %%
z= 0.1*np.arange(10)

# %%
y = (n1[0]*x+n1[2]*z)/n1[1]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z)

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import random

def fun(x, y,a,b,c):
  return a*x + b*y+c

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = y = np.arange(-10.0, 10.0, 0.1)
X, Y = np.meshgrid(x, y)
X1, Y1 = np.meshgrid(x, y)
a = -n10[0]/n10[2];b=-n10[1]/n10[2]
a1 = -n1[0]/n1[2];b1=-n1[1]/n10[2]
a2 = -n3[0]/n3[2];b2=-n3[1]/n3[2]
zs = np.array([fun(x,y,a,b,0) for x,y in zip(np.ravel(X), np.ravel(Y))])
zs1 = np.array([fun(x,y,a1,b1,10) for x,y in zip(np.ravel(X1), np.ravel(Y1))])
zs2 = np.array([fun(x,y,a2,b2,20) for x,y in zip(np.ravel(X1), np.ravel(Y1))])
Z = zs.reshape(X.shape)
Z1 = zs1.reshape(X1.shape)
Z2 = zs2.reshape(X1.shape)
fig.xmin =0
ax.plot_surface(X, Y, Z)
ax.plot_surface(X1, Y1, Z1)
ax.plot_surface(X1, Y1, Z2)
x1=np.array([0,10*n10[0]])
y1=np.array([0,10*n10[1]])
z1=np.array([0,10*n10[2]])
#Q=ax.plot(x1,y1,z1)
x2=np.array([0,10*n1[0]])
y2=np.array([0,10*n1[1]])
z2=np.array([5,5+10*n1[2]])
#Q=ax.plot(x2,y2,z1)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
scale = 15
ax.set_xlim3d(-scale,scale)
ax.set_ylim3d(-scale,scale)
ax.set_zlim3d(-scale+10,scale+10)
plt.savefig('planes.png',dpi=500)
plt.show()

# %%
dir(ax)
# Out:
# ['M',
#  '_3d_extend_contour',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__getstate__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adjustable',
#  '_agg_filter',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_autoscaleZon',
#  u'_axes_class',
#  '_axes_locator',
#  '_axis3don',
#  '_axisbelow',
#  '_axisbg',
#  '_button_press',
#  '_button_release',
#  '_cachedRenderer',
#  '_cids',
#  '_clipon',
#  '_clippath',
#  '_connected',
#  '_contains',
#  '_current_image',
#  '_cursorProps',
#  '_determine_lims',
#  '_draw_grid',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
#  '_gen_axes_spines',
#  '_generate_normals',
#  '_get_legend_handles',
#  '_get_lines',
#  '_get_patches_for_fill',
# ...

# %%
np.ar
# Out:
# u'/Users/adantra/libmesh/ultrafinance/ultrafinance/pyTaLib'

# %%
def azimuth(n):
    theta = np.arccos(n[0]/np.sqrt(1-n[2]**2))
    return theta*180.0/np.pi

# %%
az10 = azimuth(n10)

# %%
az10
# Out:
# 34.842128267282902

# %%
nn=range(10)
for i in range(10):
    nn[i]='n%i' % i+1
    print i,n%i % i+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-541-f13bfb68d56e> in <module>()
#       1 nn=range(10)
#       2 for i in range(10):
# ----> 3     nn[i]='n%i' % i+1
#       4     print i,n%i % i+1
#
# TypeError: cannot concatenate 'str' and 'int' objects

# %%
nn
# Out:
# [array([ nan,  nan,  nan]),
#  array([ 1.87,  1.26,  1.42]),
#  array([ 1.87,  1.26,  1.42]),
#  array([ 1.87,  1.26,  1.42]),
#  array([ 1.87,  1.26,  1.42]),
#  array([ 1.87,  1.26,  1.42]),
#  array([ 1.87,  1.26,  1.42]),
#  array([ 1.87,  1.26,  1.42]),
#  array([ 1.87,  1.26,  1.42]),
#  array([ 1.87,  1.26,  1.42])]

# %%
# Out:
# ['Ask',
#  'Bid',
#  'Chg',
#  'IV',
#  'IsNonstandard',
#  'Last',
#  'Open_Int',
#  'PctChg',
#  'Quote_Time',
#  'Root',
#  'T',
#  'Underlying',
#  'Underlying_Price',
#  'Vol',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
dir(data.index)
# Out:
# ['T',
#  '_MultiIndex__bounds',
#  '_MultiIndex__set_labels',
#  '_MultiIndex__set_levels',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__inv__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmul__',
#  '__rpow__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
# ...

# %%
data.index.levels[3][0]
# Out:
# u'GOOGL160422C00560000'

# %%
print pd.set_option.__doc__
# Out:
# set_option(pat, value)
#
# Sets the value of the specified option.
#
# Available options:
#
# - display.[chop_threshold, colheader_justify, column_space, date_dayfirst,
#   date_yearfirst, encoding, expand_frame_repr, float_format, height, large_repr]
# - display.latex.[escape, longtable, repr]
# - display.[line_width, max_categories, max_columns, max_colwidth,
#   max_info_columns, max_info_rows, max_rows, max_seq_items, memory_usage,
#   mpl_style, multi_sparse, notebook_repr_html, pprint_nest_depth, precision,
#   show_dimensions]
# - display.unicode.[ambiguous_as_wide, east_asian_width]
# - display.[width]
# - io.excel.xls.[writer]
# - io.excel.xlsm.[writer]
# - io.excel.xlsx.[writer]
# - io.hdf.[default_format, dropna_table]
# - mode.[chained_assignment, sim_interactive, use_inf_as_null]
#
# Parameters
# ----------
# pat : str
#     Regexp which should match a single option.
#     Note: partial matches are supported for convenience, but unless you use the
# ...

# %%
pd.set_option('display.date_dayfirst',True)

# %%
val = 5

# %%
end = int(3/2)+1
print end
# Out:
# 2

# %%
end
# Out:
# 3

# %%
def is_prime(val):
    try:
        end = int(val/2)+1
        print end
    except ValueError:
        print end
        return False
    for i in range(2,end):
        print i
        if val%i == 0:
            return False
    return True

# %%
is_prime(9)
# Out:
# 5
# 2
# 3
# False

# %%
from io import StringIO

# %%
data = {"birth":['9-1-1900','1-3-1994','2-28-1889'],
       "Name":['Fred','Marge','Henry'],
       "Color":['Red','Blue',None],
       "Number":[3,1,9]}

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
test = 'file.csv'
fout = StringIO()

# %%
aapl
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-1a8d7ab19b20> in <module>()
# ----> 1 aapl.MACD.__doc__
#
# /Users/adantra/anaconda/envs/default/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2667             if name in self._info_axis:
#    2668                 return self[name]
# -> 2669             return object.__getattribute__(self, name)
#    2670
#    2671     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'MACD'

# %%
pandasImpl.STO.__doc__
